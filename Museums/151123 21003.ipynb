# %%
import requests
from bs4 import BeautifulSoup
from lxml import etree

import requests
from lxml import html

# %% [markdown]
# ## Функции

# %%
# def get_div(xpath):
#     # Парсинг HTML
#     tree = html.fromstring(response.text)

#     # Выбор элемента
#     selected_element = tree.xpath("//div[@data-id='28']")[0]

#     # # Создаем временный элемент и копируем содержимое выбранного элемента
#     temp_element = html.Element("div")
#     temp_element.extend(selected_element)

#     # Получение HTML-разметки только для выбранного элемента
#     html_representation = html.tostring(temp_element, encoding='unicode', method='html')

# %%
def get_div(tree, xpath_format):
    list_divs = []
    
    
#     tree = html.fromstring(response)


    # Выбор элемента
    selected_element = tree.xpath(xpath_format)


    for div in selected_element:

        # # Создаем временный элемент и копируем содержимое выбранного элемента
        temp_element = html.Element("div")
        temp_element.extend(div)

        # Получение HTML-разметки только для выбранного элемента
        html_representation = html.tostring(temp_element, encoding='unicode', method='html')

        list_divs.append(html_representation)
    return list_divs

# %% [markdown]
# # Main

# %%
dict_info = {}

list_sites    = ['https://stalingrad-battle.ru/about/m-news/', 'https://victorymuseum.ru/playbill/', 'https://blokadamus.ru/музей-обороны-и-блокады-ленинграда/события/']
xpaths_format = ["//div[@data-id='28']", '//*[@class="item"]', '//*[@class="elementor-post__card"]']

for site, xpath_format in zip(list_sites, xpaths_format):
    response = requests.get(site)

    if response.status_code == 200:
        # Создаем объект дерева HTML из содержимого ответа
        tree = html.fromstring(response.text)
        dict_info[site] = get_div(tree, xpath_format)
    else:
        print(f'Ошибка статуса {response.status_code} для {sites}')

# %%
dict_info = {}

list_sites    = ['https://victorymuseum.ru/playbill/', 'https://stalingrad-battle.ru/about/m-news/', 
                 'https://blokadamus.ru/музей-обороны-и-блокады-ленинграда/события/']

xpaths_format = ["//div[@data-id='28']", '//*[@class="item"]', '//*[@class="elementor-post__card"]', 
                ]

for site, xpath_format in zip(list_sites, xpaths_format):
    response = requests.get(site)

    if response.status_code == 200:
        # Создаем объект дерева HTML из содержимого ответа
        tree = html.fromstring(response.text)
        dict_info[site] = get_div(tree, xpath_format)
    else:
        print(f'Ошибка статуса {response.status_code} для {sites}')

# %%
dict_info = {}

list_sites    = ['http://www.cmaf.ru/']

xpaths_format = ['//*[@class="news-item"]']

for site, xpath_format in zip(list_sites, xpaths_format):
    response = requests.get(site)

    if response.status_code == 200:
        # Создаем объект дерева HTML из содержимого ответа
        tree = html.fromstring(response.text)
        dict_info[site] = get_div(tree, xpath_format)
    else:
        print(f'Ошибка статуса {response.status_code} для {sites}')

# %%
<p class="news-item">
	
</p><tr id="bx_3218110189_3942">
			
					<span class="news-date-time">21 Ноября 2023</span>
		               
									<a style="font-size: 12px; font-weight: bold; margin: 0;" href="/news/news-3942/">Внимание! Изменения в работе музея 22 ноября</a>
                
					                
						
					</tr>
<br>
<p class="news-item">
	
</p><tr id="bx_3218110189_3931">
			
					<span class="news-date-time">31 Октября 2023</span>
		               
									<a style="font-size: 12px; font-weight: bold; margin: 0;" href="/news/news-3931/">Режим работы музея 4-6 ноября</a>
                
					                
						
					</tr>
<br>

</div>
 </div>
# Out:
# <p class="news-item">
#
# </p><tr id="bx_3218110189_3942">
#
# 					<span class="news-date-time">21 Ноября 2023</span>
#
# 									<a style="font-size: 12px; font-weight: bold; margin: 0;" href="/news/news-3942/">Внимание! Изменения в работе музея 22 ноября</a>
#
#
#
# 					</tr>
# <br>
# <p class="news-item">
#
# </p><tr id="bx_3218110189_3931">
#
# 					<span class="news-date-time">31 Октября 2023</span>
#
# 									<a style="font-size: 12px; font-weight: bold; margin: 0;" href="/news/news-3931/">Режим работы музея 4-6 ноября</a>
#
#
#
# 					</tr>
# <br>
#
# </div>
#  </div>
#
# <!-- /important news -->
#
#
# <p align="center"><img src="/img/design/calendar-date-logo.png" width="210" height="47"></p>
# <div style="width:300px;">
#             <div id="my-calendar"></div>
#
#             <script type="application/javascript">
#                 $(document).ready(function () {
#                     $("#my-calendar").zabuto_calendar({
#                         ajax: {
#                             url: "calendar/show_data.php",
#                             modal: true
#                         }
#                     });
#                 });
#             </script>
# </div>
#
#
# <!--
#     <p align="center">
# <br><br>
# 	<a href="http://sc.mil.ru/social/culture/award/info.htm" ><img src="/img/banners/banner_award_2017.png" width="240" alt=""  /></a>
# 	</p>
#
#
#     <p align="center">
# <br><br>
# 	<a href="https://1418museum.ru/" target="_blank"><img src="/img/banners/doroga.png" width="240" height="160" alt="ДОРОГА ПАМЯТИ"  /></a>
# 	</p>
# -->
#
#
# <!-- end #sidebar-left -->
#  </div>
#
#   <div id="sidebar-right">
#
# <style type="text/css">
# .cf:before, .cf:after{
#     content:"";
#     display:table;
# }
# .cf:after{
#     clear:both;
# }
# .cf{
#     zoom:1;
# }
# /* Стили для контейнера формы */
# .form-wrapper {
#     width: 300px;
#     margin: 30px auto 50px auto;
# 	padding-left:10px;
# }
# /* Стили поля ввода текста */
# .form-wrapper input {
#     width: 190px;
#     height: 40px;
#     padding: 10px 5px;
#     float: left;
#     font: bold 15px 'lucida sans', 'trebuchet MS', 'Tahoma';
#     border: 0;
#     background: #eee;
#     border-radius: 3px 0 0 3px;
# }
# .form-wrapper input:focus {
#     outline: 0;
#     background: #fff;
#     box-shadow: 0 0 2px rgba(0,0,0,.8) inset;
# }
# .form-wrapper input::-webkit-input-placeholder {
#    color: #999;
#    font-weight: normal;
#    font-style: italic;
# }
# .form-wrapper input:-moz-placeholder {
#     color: #999;
#     font-weight: normal;
#     font-style: italic;
# }
# .form-wrapper input:-ms-input-placeholder {
#     color: #999;
#     font-weight: normal;
#     font-style: italic;
# }
# /* Кнопка отправки формы */
# .form-wrapper button {
#     overflow: visible;
#     position: relative;
#     float: right;
#     border: 0;
#     padding: 0;
#     cursor: pointer;
#     height: 40px;
#     width: 90px;
#     font: bold 15px/40px 'lucida sans', 'trebuchet MS', 'Tahoma';
#     color: #fff;
#     text-transform: uppercase;
#     background: #912121;
#     border-radius: 0 3px 3px 0;
#     text-shadow: 0 -1px 0 rgba(0, 0 ,0, .3);
# }
# .form-wrapper button:hover{
#     background: #e54040;
# }
# .form-wrapper button:active,
# .form-wrapper button:focus{
#     background: #c42f2f;
#     outline: 0;
# }
# .form-wrapper button:before { /* стрелка влево */
#     content: '';
#     position: absolute;
#     border-width: 8px 8px 8px 0;
#     border-style: solid solid solid none;
#     border-color: transparent #912121 transparent;
#     top: 12px;
#     left: -6px;
# }
# .form-wrapper button:hover:before{
#     border-right-color: #e54040;
# }
# .form-wrapper button:focus:before,
# .form-wrapper button:active:before{
#         border-right-color: #c42f2f;
# }
# .form-wrapper button::-moz-focus-inner { /* Удаляем дополнительное пространство рядом с кнопкой в Mozilla Firefox */
#     border: 0;
#     padding: 0;
# }
# </style>
# <form class="form-wrapper cf" action="/search/" method="get">
#    <input type="hidden" name="tags" value="">
#    <input type="text" placeholder="Поиск" name="q" id="cond" required>
#    <input type="hidden" name="how" value="r">
#    <button type="submit">Искать</button>
# </form>
#
#
# <script src="https://listim.com/embed/widget.js"></script>
# <script>var listimWidget = new ListimWidget(231, 'shows');</script>
#
# <p align="center"><span onclick="listimWidget.openModal()" style="color: #faddde;border: solid 1px #980c10;background: #d81b21;background: -webkit-gradient(linear, left top, left bottom, from(#ed1c24), to(#aa1317));background: -moz-linear-gradient(top, #ed1c24, #aa1317);filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#ed1c24', endColorstr='#aa1317');display: inline-block;zoom: 1;vertical-align: baseline;margin: 0 2px;outline: none;cursor: pointer;text-align: center;text-decoration: none;font: 18px/100% Arial, Helvetica, sans-serif;padding: .5em 2em .55em;text-shadow: 0 1px 1px rgba(0,0,0,.3);-webkit-border-radius: .5em;-moz-border-radius: .5em;border-radius: .5em;-webkit-box-shadow: 0 1px 2px rgba(0,0,0,.2);-moz-box-shadow: 0 1px 2px rgba(0,0,0,.2);box-shadow: 0 1px 2px rgba(0,0,0,.2);">Купить билет on-line</span></p>
#
# <!-- /онлайн покупка билетов -->
# <br><br>
#
#
#     <p>Адрес:
#       <br>
#      129272, г.Москва, ул.Советской Армии, д.2, стр.1
#       <br>
# <a href="/visitor/cont/">Схема проезда</a><br>
#       <br>
#      <b>АВТОИНФОРМАТОР:</b><br>
#       <span style="font-size:18px;font-weight: bold;">✆</span> 8 (495) 681-48-77<br>
#       <br>
#      Экскурсионное бюро (кроме Пн и Вт):
#       <br>
#      <span style="font-size:18px;font-weight: bold;">✆</span> 8 (495) 681-63-03<br>
# 	 <span style="font-size:18px;font-weight: bold;">✆</span> 8 (495) 681-58-98<br>
#
#
#       <br><br>
# 	  E-mail: 	<a href="&lt;!--p2pi.ru:" encrypt email script-->
# <script type="text/javascript">var x1,x2,x3,x4,x5,x6,x7; x1='<a href="'; x1+='mai'; x1+='lto:'; x2 ='&#99;&#109;&#118;&#115;&#95;&#100;&#109;'; x3 ='&#64;'; x4 ='&#109;&#105;&#108;&#46;&#114;&#117;'; x5 ='">'; x6 = x2+'&#64;'+x4 ; x7 ='</a>';document.write(x1+x2+x3+x4+x5+x6+x7);</script>
# <!--End Encrypt--></a>
# <br>
# <br>
#
#      Секретарь:
# 	       <br>
#
#      <span style="font-size:18px;font-weight: bold;">✆</span> 8 (495) 681-18-80
#
#       <br>
#      <!--Факс:
#       <br />
#      <span style="font-size:18px;">&#128224;</span>&nbsp;8 (495) 681-47-63
#       <br />
#      -->
# 	  </p><center><hr width="80%"></center>
# 	<center>
#  <table border="0" width="80%" style="font-family: 'Helvetica Neue',Helvetica,Arial,sans-serif;font-size: 14px;">
# 	  <tbody><tr>
# 	   <th colspan="2">Режим работы музея:</th>
# 	  </tr>
#
# 	  <tr>
#        <td><span style="
#     display: inline-block;
#     width: 36px;
#     height: 18px;
#     line-height: 16px;
#     text-align: center;
#     background: #d6d6d6;
#     border-radius: 10px;
#     -moz-border-radius: 10px;
#     -webkit-border-radius: 10px;
#     margin-right: 3px;color:red;
#     ">Пн</span> <span style="
#     display: inline-block;
#     width: 36px;
#     height: 18px;
#     line-height: 16px;
#     text-align: center;
#     background: #d6d6d6;
#     border-radius: 10px;
#     -moz-border-radius: 10px;
#     -webkit-border-radius: 10px;
#     margin-right: 3px;color:red;
#     ">Вт</span></td>
# 	   <td> <b>- музей закрыт</b></td>
# 	  </tr>
#
# 	  <tr>
# 	   <td><span style="
#     display: inline-block;
#     width: 33px;
#     height: 16px;
#     line-height: 16px;
#     text-align: center;
#     background: #d6d6d6;
#     border-radius: 10px;
#     -moz-border-radius: 10px;
#     -webkit-border-radius: 10px;
#     margin-right: 3px;
#     ">Ср</span> - <span style="
#     display: inline-block;
#     width: 33px;
#     height: 16px;
#     line-height: 16px;
#     text-align: center;
#     background: #d6d6d6;
#     border-radius: 10px;
#     -moz-border-radius: 10px;
#     -webkit-border-radius: 10px;
#     margin-right: 3px;
#     ">Пт</span></td>
# 	   <td> - с 10:00 до 17:00</td>
# 	  </tr>
#
# 	  <td><span style="
#     display: inline-block;
#     width: 33px;
#     height: 16px;
#     line-height: 16px;
#     text-align: center;
#     background: #d6d6d6;
#     border-radius: 10px;
#     -moz-border-radius: 10px;
#     -webkit-border-radius: 10px;
#     margin-right: 3px;
#     ">Сб</span> - <span style="
#     display: inline-block;
#     width: 33px;
#     height: 16px;
#     line-height: 16px;
#     text-align: center;
#     background: #d6d6d6;
#     border-radius: 10px;
#     -moz-border-radius: 10px;
#     -webkit-border-radius: 10px;
#     margin-right: 3px;
#     ">Вс</span></td>
# 	   <td> - с 10:00 до 17:00</td>
#
#
# 	  <tr>
#        <td colspan="2"><font size="-1">Кассы прекращают работу за 30 минут до закрытия!</font></td>
# 	  </tr>
# 	   </tbody></table>
#
# </center>
# 	  <center><hr width="80%"></center>
#     <center>
# 	  <table border="0" width="80%">
# 	  <tr>
# 	   </tr><tr><a href="/visitor/price/">Цены на входные билеты<br> и экскурсионное обслуживание</a><br></tr>
#
# 	</table>
# 	</center>
#
#     <br>
#
# <noindex><center><p><a href="http://quality.mkrf.ru/mark/?orgid=0373100001101" target="_blank" ref="nofollow" style="text-decoration: none;"><img src="/img/banners/logo_qc.png" width="81" height="61" alt="оценка качества услуг"><br><span style="font-size: 18px;">Оценка качества услуг</span></a></p></center></noindex>
# <br>
# <br>
#
#
# <style type="text/css">
# .frompic {
#     position: relative;
#     display:inline-block;
#     vertizl-align:top;
#     width: 150px;
#     height: 150px;
# 	margin-left:85px;
#     /* определение глубины поворота */
#     -webkit-perspective: 600px; /* webkit */
#     -moz-perspective: 600px; /* mozilla */
#     -ms-perspective: 600px; /* IE 10 */
#     -o-perspective: 600px; /* opera */
#     perspective: 600px; /* стандартное указание свойства */
#
# }
# .block {
#     -webkit-transition: -webkit-transform 0.5s;
#     -moz-transition: -moz-transform 0.5s;
#     -ms-transition: -moz-transform 0.5s;
#     -o-transition: -o-transform 0.5s;
#     transition: transform 0.5s; /* продолжительность поворота */
#     -webkit-transform-style: preserve-3d;
#     -moz-transform-style: preserve-3d;
#     -ms-transform-style: preserve-3d;
#     -o-transform-style: preserve-3d;
#     transform-style: preserve-3d;
# }
# .block:hover {
#     -webkit-transform: rotateY( 180deg );
#     -moz-transform: rotateY( 180deg );
#     -ms-transform: rotateY( 180deg );
#     -o-transform: rotateY( 180deg );
#     transform: rotateY( 180deg );
# }
# .frompic img {
#     position: absolute;
#     display:block;
#     top: 0px;
#     left: 0px;
#     width: 150px;
#     height: 150px;
#     -webkit-backface-visibility: hidden;
#     -moz-backface-visibility: hidden;
#     -ms-backface-visibility: hidden;
#     -o-backface-visibility: hidden;
#     backface-visibility: hidden;    /* скрытия контента элемента
#  после поворота */
# }
# .frompic {
#     left:0px;
# }
# .img2 {
#     -webkit-transform: rotateY( 180deg );
#     -moz-transform: rotateY( 180deg );
#     -ms-transform: rotateY(180deg);
#     -o-transform: rotateY( 180deg );
#     transform: rotateY( 180deg );   /* устанавливаем начальное
#  положение задней стороны */
# }
# </style>
# <!--
# <div class="frompic pic1" id="pic1">
#     <div class="block">
# <p align="center">
# 	<a href="/ekspo/virtual/" >
#         <img class="img1" src="/img/design/icon-360-150x150.png" alt="Обзорная панорама" >
#         <img class="img2" src="/img/design/icon-360-150x150_1.png" alt="Обзорная панорама" >
# 	</a>
# </p>
#  </div>
# </div>
#
#
#     <p align="center">
# <br><br>
# 	<img src="/img/banners/logo-redflags_2019.gif" width="240" height="160" alt=""  />
# 	</p>
# 	<p align="center">
#
# 	</p>
# -->
#
#
#
#     <p align="center">
#
#
# 	</p>
# 	<br>
# 	<br>
# <p align="center">
# <br><br>
# 	<a href="https://nuremberg.media/" target="_blank"><img src="/img/banners/nurnberg.jpg" width="240" height="160" alt="НАЧАЛО МИРА"></a>
# 	</p>
#
# </div>
#
# 	<br>
#
#
#
#   <div id="mainContent">
#
# <div class="reg-news">
#   <p style="font-weight: bold; margin-bottom: 19px;"> <a href="/news/rss/rss.php" title="rss" target="_self"><img alt="RSS" src="/img/design/rss/png/feed-icon-16x16.png" border="0" align="right"></a>
#
# </p><div class="news-list">
#
# <p class="news-item">
# 	</p><tr id="bx_651765591_3942">
#
#
#
# 									<a style="font-size: 15px; font-weight: bold; margin: 0;" href="/news/news-3942/">Внимание! Изменения в работе музея 22 ноября</a>
#
#
# 					<p style="margin: 0;"></p><p>Уважаемые посетители! В эту среду по техническим причинам музей работает с 13:00 часов.</p>
#
# <table border="0" width="100%">
#  <tr>
#   <td align="left">
#   			<span class="news-date-time">21 Ноября 2023</span>
#     </td>
#   <td align="right"><a style="font-size: 11px; font-weight: bold; margin: 0; color: #006699;" href="/news/news-3942/">подробнее &gt;&gt;</a></td>
#  </tr>
# </table>
# <br>
#
#
#
#
#
# 					</tr>
#
# <p class="news-item">
# 	</p><tr id="bx_651765591_3941">
#
#
#
# 									<a style="font-size: 15px; font-weight: bold; margin: 0;" href="/news/news-3941/">Более 200 человек приняли участие в Географическом диктанте на площадках ЦМВС РФ и его филиалов </a>
#
#
# 					<p style="margin: 0;"></p><p>
# 	 19 ноября наша музейная семья принимала участников ежегодной международной акции «Географический диктант». В этот раз кроме ЦМВС РФ площадками проекта выступили Центральный музей Военно-Воздушных Сил, Музей истории ВДВ и Музей Ракетных войск стратегического назначения. Всего на наших площадках Диктант написали 225 человек. Для участников проекта вход в ЦМВС РФ был бесплатным.
# </p>
#
# <table border="0" width="100%">
#  <tr>
#   <td align="left">
#   			<span class="news-date-time">20 Ноября 2023</span>
#     </td>
#   <td align="right"><a style="font-size: 11px; font-weight: bold; margin: 0; color: #006699;" href="/news/news-3941/">подробнее &gt;&gt;</a></td>
#  </tr>
# </table>
# <br>
#
#
#
#
#
# 					</tr>
#
# <p class="news-item">
# 	</p><tr id="bx_651765591_3940">
#
#
#
# 									<a style="font-size: 15px; font-weight: bold; margin: 0;" href="/news/news-3940/">Подмосковные партизаны и ослабевший «Тайфун»: музей приглашает на кинопоказ</a>
#
#
# 					<p style="margin: 0;"></p><p>В это воскресенье, 19 ноября, в музее пройдет традиционный показ документального сериала
# «Фронтовая Москва. История Победы» (2011 г., 12+). Эпизод «Война в тылу врага» расскажет о
# формировании советского партизанского движения в 1941 году и его значении для защиты
# столицы СССР. Последующий выпуск «Враг у ворот» обратится к переломному моменту в обороне
# города и причинам, почему планы немцев о взятии Москвы рухнули.⁠</p>
#
# <table border="0" width="100%">
#  <tr>
#   <td align="left">
#   			<span class="news-date-time">16 Ноября 2023</span>
#     </td>
#   <td align="right"><a style="font-size: 11px; font-weight: bold; margin: 0; color: #006699;" href="/news/news-3940/">подробнее &gt;&gt;</a></td>
#  </tr>
# </table>
# <br>
#
#
#
#
#
# 					</tr>
#
# <p class="news-item">
# 	</p><tr id="bx_651765591_3939">
#
#
#
# 									<a style="font-size: 15px; font-weight: bold; margin: 0;" href="/news/news-3939/">Научная конференция в музее: как 1943 год изменил ход войны</a>
#
#
# 					<p style="margin: 0;"></p><p>
# 	 14 ноября в нашем музее прошла международная научно-практическая конференция «1943 год – год коренного перелома в Великой Отечественной войне 1941-1945 гг.», организованная ЦМВС РФ. Ученые-историки из России и ряда стран СНГ представили свежие исследования, посвященные событиям переломного года. Несмотря на обилие поднятых тем, собравшиеся были едины в главном: 80 лет назад совместный подвиг армии и народа СССР окончательно переломил ход Великой Отечественной войны.⁠
# </p>
#
# <table border="0" width="100%">
#  <tr>
#   <td align="left">
#   			<span class="news-date-time">15 Ноября 2023</span>
#     </td>
#   <td align="right"><a style="font-size: 11px; font-weight: bold; margin: 0; color: #006699;" href="/news/news-3939/">подробнее &gt;&gt;</a></td>
#  </tr>
# </table>
# <br>
#
#
#
#
#
# 					</tr>
#
# <p class="news-item">
# 	</p><tr id="bx_651765591_3938">
#
#
#
# 									<a style="font-size: 15px; font-weight: bold; margin: 0;" href="/news/news-3938/">Вокруг России за один час – музей проведет Географический диктант</a>
#
#
# 					<p style="margin: 0;"></p><p>
# 	 Интересуетесь географией и историей? Приглашаем в это воскресенье в ЦМВС РФ на «Географический диктант»! 19 ноября наш музей традиционно выступит площадкой для этой любимой многими акции.⁠
# </p>
#
# <table border="0" width="100%">
#  <tr>
#   <td align="left">
#   			<span class="news-date-time">15 Ноября 2023</span>
#     </td>
#   <td align="right"><a style="font-size: 11px; font-weight: bold; margin: 0; color: #006699;" href="/news/news-3938/">подробнее &gt;&gt;</a></td>
#  </tr>
# </table>
# <br>
#
#
#
#
#
# 					</tr>
#
# <p class="news-item">
# 	</p><tr id="bx_651765591_3937">
#
#
#
# 									<a style="font-size: 15px; font-weight: bold; margin: 0;" href="/news/news-3937/">12 ноября покажем документальное кино о сложнейшем периоде обороны Москвы в 1941 году</a>
#
#
# 					<p style="margin: 0;"></p><p>
# 	 В это воскресенье в музее пройдет традиционный показ документального сериала «Фронтовая Москва. История Победы» (2011 г.). Эпизоды «Эвакуация» и «Парад надежды» расскажут зрителям о сложнейшем периоде обороны столицы, когда немцы буквально стояли под стенами города, а первые лица СССР колебались: давать ли последний бой за первопрестольную? Чем закончилась эта история вы знаете, а яркие штрихи времени можно увидеть в увлекательном кинопроекте.
# </p>
#
# <table border="0" width="100%">
#  <tr>
#   <td align="left">
#   			<span class="news-date-time">10 Ноября 2023</span>
#     </td>
#   <td align="right"><a style="font-size: 11px; font-weight: bold; margin: 0; color: #006699;" href="/news/news-3937/">подробнее &gt;&gt;</a></td>
#  </tr>
# </table>
# <br>
#
#
#
#
#
# 					</tr>
#
#
# </div>
#
#  </div>
#
# <p align="center"><a style="font-size: 15px; font-weight: bold; margin: 0;" href="/news/archive/">Архив новостей</a></p>
#
#  </div>
#
# <!-- end #mainContent -->
#
#
#   <div id="footer">
#    <hr size="1px" width="95%" color="#b8b9bb">
#
# <table width="100%" cellspacing="0" cellpadding="0" border="0" align="center">
#  <tr>
#   <td align="left" width="320">
#           <table cellspacing="4" cellpadding="4" border="0">
# 		   <tr>
# 		    <td>
# 			 <noindex><a target="_blank" rel="nofollow" href="http://www.tripadvisor.ru/Attraction_Review-g298484-d549927-Reviews-Central_Armed_Forces_Museum-Moscow_Central_Russia.html"><img src="http://cmaf.ru/img/ico_tripadvisor.png" width="32" height="32" alt="Центральный музей Вооруженных Сил"></a></noindex>
# 			</td>
# 		    <td>
# 			 <noindex><a target="_blank" rel="nofollow" href="https://vk.com/cmaf_rf"><img src="http://cmaf.ru/img/ico_vkontakte.png" width="32" height="32" alt="Центральный музей Вооруженных Сил"></a></noindex>
# 			</td>
# 			<td>
# 			 <noindex><a target="_blank" rel="nofollow" href="https://ok.ru/group/61858477375521"><img src="http://cmaf.ru/img/ico_ok.png" width="32" height="32" alt="Центральный музей Вооруженных Сил"></a></noindex>
# 			</td>
# 			<td>
# 			 <noindex><a target="_blank" rel="nofollow" href="https://zen.yandex.ru/id/622865de1f3a3e72bcaf3778"><img src="http://cmaf.ru/img/ico_zen.png" width="24" height="24" alt="Центральный музей Вооруженных Сил"></a></noindex>
# 			</td>
# 		   </tr>
# 		  </table>
#   </td>
#   <td>
#
#     <p style="line-height:23px; font-size:11px;text-align:center;">© 2005-2023 Центральный музей Вооруженных Сил Российской Федерации. Все права защищены.</p>
#
# <!-- /error on site -->
# 	  <p style="line-height:23px; font-size:11px;text-align:center;">Ошибка в тексте? Выделите её мышкой и нажмите: <span style="background:none repeat scroll 0 0 #ECECEC;border-color:#FFFFFF #BBB8AB #BBB8AB #FFFFFF;border-style:solid;border-width:1px;padding:1px 4px;">Ctrl</span> + <span style="background:none repeat scroll 0 0 #ECECEC;border-color:#FFFFFF #BBB8AB #BBB8AB #FFFFFF;border-style:solid;border-width:1px;padding:1px 4px;">Enter</span></p>
#
#
#   </td>
#
#   <td align="right" width="320">
#    <table cellspacing="2" cellpadding="2" border="0">
#         <tr>
#  <td>
#  <a target="_top" href="http://mil.ru"><img src="http://cmaf.ru/img/design/mil_88x31.png" border="0" width="88" height="31" alt="Министерство обороны Российской Федерации"></a>
#  </td>
#  <td>
# <!-- Yandex.Metrika informer -->
# <a href="https://metrika.yandex.ru/stat/?id=42684374&amp;from=informer" target="_blank" rel="nofollow"><img src="https://informer.yandex.ru/informer/42684374/3_0_FFFFFFFF_EFEFEFFF_0_pageviews" style="width:88px; height:31px; border:0;" alt="Яндекс.Метрика" title="Яндекс.Метрика: данные за сегодня (просмотры, визиты и уникальные посетители)" class="ym-advanced-informer" data-cid="42684374" data-lang="ru"></a>
# <!-- /Yandex.Metrika informer -->
#
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#     (function (d, w, c) {
#         (w[c] = w[c] || []).push(function() {
#             try {
#                 w.yaCounter42684374 = new Ya.Metrika({
#                     id:42684374,
#                     clickmap:true,
#                     trackLinks:true,
#                     accurateTrackBounce:true,
#                     webvisor:true,
#                     trackHash:true
#                 });
#             } catch(e) { }
#         });
#
#         var n = d.getElementsByTagName("script")[0],
#             s = d.createElement("script"),
#             f = function () { n.parentNode.insertBefore(s, n); };
#         s.type = "text/javascript";
#         s.async = true;
#         s.src = "https://mc.yandex.ru/metrika/watch.js";
#
#         if (w.opera == "[object Opera]") {
#             d.addEventListener("DOMContentLoaded", f, false);
#         } else { f(); }
#     })(document, window, "yandex_metrika_callbacks");
# </script>
# <noscript><div><img src="https://mc.yandex.ru/watch/42684374" style="position:absolute; left:-9999px;" alt=""></div></noscript>
# <!-- /Yandex.Metrika counter -->
#  </td>
#  <td>
# <!-- noindex --><a href="http://cdra.ru/" rel="nofollow"><img src="http://cmaf.ru/img/banners/cdra_88x31.png" border="0" height="31" width="88" alt="Центральный дом Российской Армии"></a><!-- /noindex -->
#  </td>
#  </tr>
#      </table>
#
#   </td>
#  </tr>
# </table>
#
#
#
#
#
# <br>
#    <!-- end #footer -->
#  </div>
#
# <!-- end #container -->
#  </div>
#  </body>
# </html>

# %%
for site, xpath_format in zip(list_sites, xpaths_format):
    response = requests.get(site)

    if response.status_code == 200:
        # Создаем объект дерева HTML из содержимого ответа
        tree = html.fromstring(response.text)
        print('ok')
# Out:
# ok

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# Найти первый элемент <p> с классом "news-item"
first_news_item = soup.find('p', class_='news-item')

# Вывести содержимое найденного элемента
print(first_news_item)
# Out:
# <p class="news-item">
# <tr id="bx_3218110189_3942">
# <span class="news-date-time">21 Ноября 2023</span>
# <a href="/news/news-3942/" style="font-size: 12px; font-weight: bold; margin: 0;">Внимание! Изменения в работе музея 22 ноября</a>
# </tr></p>

# %%
temp_element = html.Element("p")

# %%
temp_element.extend(temp_element)

# %%
print(html.tostring(temp_element, encoding='unicode', method='html'))
# Out:
# <p></p>

# %%
dict_info
# Out:
# {'http://www.cmaf.ru/': ['<div></div>',
#   '<div></div>',
#   '<div></div>',
#   '<div></div>',
#   '<div></div>',
#   '<div></div>',
#   '<div></div>',
#   '<div></div>']}

# %%
selected_element =

# %%
selected_element[3].text_content()
# Out:
# '\n\t'

# %%
print(div)
# Out:
#
#
#
# 					21 Ноября 2023
#
# 									Внимание! Изменения в работе музея 22 ноября
#
#
#
#
#
#
#
#
#
# 					31 Октября 2023
#
# 									Режим работы музея 4-6 ноября

# %%
div = selected_element[0]

temp_element = html.Element("a")
# temp_element.extend(elem)

# # Получение HTML-разметки только для выбранного элемента
# html_representation = html.tostring(temp_element, encoding='unicode', method='html')

# print(html_representation)

# %%
html_representation = html.tostring(temp_element, encoding='unicode', method='html')

# %%
html_representation
# Out:
# '<a></a>'

# %%
стоп
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 стоп
#
# NameError: name 'стоп' is not defined

# %% [markdown]
# ## Как можно парсить

# %%
cnjg

# %%
# Парсинг HTML
tree = html.fromstring(response.text)

# Выбор элемента
selected_element = tree.xpath("//div[@data-id='28']")[0]

# # Создаем временный элемент и копируем содержимое выбранного элемента
temp_element = html.Element("div")

temp_element.extend(selected_element)

# Получение HTML-разметки только для выбранного элемента
html_representation = html.tostring(temp_element, encoding='unicode', method='html')

print(html_representation)

# %%
# Парсинг HTML
tree = html.fromstring(response.text)

# Выбор элемента
selected_element = tree.xpath("//div[@data-id='28']")[0]

# # Создаем временный элемент и копируем содержимое выбранного элемента
temp_element = html.Element("div")
temp_element.extend(selected_element)

# Получение HTML-разметки только для выбранного элемента
html_representation = html.tostring(temp_element, encoding='unicode', method='html')

print(html_representation)
